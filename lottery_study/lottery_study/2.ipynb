# %% [markdown]
# # Part 2

# %%
import pandas as pd

# Load the Stata file
file_path = r'C:\Users\clint\Desktop\Coding Task Darthmouth\lottery_study\lottery_study\lottery_study.dta'
df = pd.read_stata(file_path)

# Display the first few rows of the dataframe
df
# Out:
# C:\Users\clint\AppData\Local\Temp\ipykernel_37132\2998904404.py:5: UnicodeWarning:
# One or more strings in the dta file could not be decoded using utf-8, and
# so the fallback encoding of latin-1 is being used.  This can happen when a file
# has been incorrectly encoded by Stata or some other software. You should verify
# the string values returned are correct.
#   df = pd.read_stata(file_path)
#                     ideology  religion       risk_seeking expend_total  \
# 0     Extremely Conservative       1.0                 -3          0.0
# 1                   Moderate       0.0                 -4         10.0
# 2      Slightly Conservative       1.0                 -4          0.0
# 3           Slightly Liberal       0.0                 -3          0.0
# 4               Conservative       1.0                 -4          1.0
# ...                      ...       ...                ...          ...
# 2885                 Liberal       0.0                 -4         10.0
# 2886            Conservative       0.0  -7 - Very willing         10.0
# 2887       Extremely Liberal       0.0                 -4          1.0
# 2888            Conservative       1.0                 -3          0.0
# 2889                Moderate       0.0                 -4         26.0
#
#                    seems_fun          enjoy_thinking          self_control  \
# 0     -3 - Strongly Disagree  -3 - Strongly Disagree  0 - The right amount
# 1                0 - Neutral             0 - Neutral  0 - The right amount
# 2                0 - Neutral                       1  0 - The right amount
# 3                0 - Neutral      3 - Strongly Agree   -3 - Far too little
# 4                          1      3 - Strongly Agree  0 - The right amount
# ...                      ...                     ...                   ...
# 2885                       2                       2  0 - The right amount
# 2886                       1                       1  0 - The right amount
# 2887                       1                       1  0 - The right amount
# 2888             0 - Neutral                      -2  0 - The right amount
# 2889             0 - Neutral      3 - Strongly Agree  0 - The right amount
#
#                                           risk_aversion  gender   age  ...  \
# 0     Average financial risks expecting to earn aver...    Male  72.0  ...
# 1     Average financial risks expecting to earn aver...  Female  61.0  ...
# 2     Above-average financial risks expecting to ear...    Male  30.0  ...
# 3     Above-average financial risks expecting to ear...  Female  68.0  ...
# 4     Average financial risks expecting to earn aver...    Male  68.0  ...
# ...                                                 ...     ...   ...  ...
# 2885  Average financial risks expecting to earn aver...    Male  66.0  ...
# 2886  Average financial risks expecting to earn aver...    Male  28.0  ...
# 2887  Above-average financial risks expecting to ear...  Female  67.0  ...
# 2888  Average financial risks expecting to earn aver...  Female  57.0  ...
# 2889                                No financial risks.  Female  48.0  ...
#
#      overconfidence  lottery_payout happiness  financial_literacy  \
# 0               0.0            0.35       3.0                 0.8
# 1               1.0            0.25       5.0                 1.0
# 2               0.0            0.25       0.0                 1.0
# 3               0.0            0.75       9.0                 0.6
# 4               0.0            0.45       1.0                 1.0
# ...             ...             ...       ...                 ...
# 2885            0.1            0.55       9.0                 0.6
# 2886            0.0            0.05       1.0                 1.0
# 2887            0.0            0.05      -1.0                 1.0
# 2888            0.0            0.25       5.0                 1.0
# 2889            0.0            0.35       NaN                 1.0
#
#       financial_numeracy  gamblers_fallacy  non_belief_lln  ev_miscalculation  \
# 0               0.666667          0.666667        0.138633               0.50
# 1               1.000000          0.000000        0.427033               0.50
# 2               1.000000          0.000000        0.597033               1.00
# 3               0.333333          0.000000        0.510367               1.00
# 4               1.000000          0.000000        0.427033               0.75
# ...                  ...               ...             ...                ...
# 2885            1.000000          1.000000        0.122900               0.75
# 2886            0.666667          0.000000        0.427033               1.00
# 2887            0.666667          0.666667        0.460367               1.00
# 2888            0.666667          0.666667        0.273700               0.50
# 2889            0.666667          1.000000        0.608840               1.00
#
#       income_effects_delta_pct  state
# 0                          0.0     AK
# 1                          7.5     AK
# 2                          0.0     AK
# 3                        -50.0     AK
# 4                          NaN     AL
# ...                        ...    ...
# 2885                       0.0     WV
# 2886                       0.0     WY
# 2887                       0.0     WY
# 2888                       0.0     WY
# 2889                       0.0     WY
#
# [2890 rows x 30 columns]

# %%
# change the data type of the column 'expend_total' to numeric
df['expend_total'] = pd.to_numeric(df['expend_total'], errors='coerce')

# %%
# Define the threshold for outliers
threshold = 1901.0

# Filter out the outliers
df = df[df['expend_total'] <= threshold]

# %%
income_gender_tabulation = pd.crosstab(df['income'], df['gender'])
income_gender_tabulation
# Out:
# gender  Male  Female
# income
# 5.0       18      28
# 7.5       17      44
# 12.5      42      62
# 17.5      39      69
# 22.5      75      84
# 27.5      72      94
# 32.5      76      83
# 37.5      61      73
# 45.0     128     124
# 55.0     142     127
# 67.5     186     159
# 80.0      81      64
# 92.5     144     138
# 112.5    137     129
# 137.5     97      61
# 162.5     57      38
# 187.5     21      23
# 250.0     53      41

# %% [markdown]
# # Part 3

# %%
age_summary = df['age'].describe()
age_summary
# Out:
# count    2887.000000
# mean       48.879806
# std        16.901751
# min        18.000000
# 25%        34.000000
# 50%        49.000000
# 75%        63.000000
# max       145.000000
# Name: age, dtype: float64

# %%
mean_age = age_summary['mean']
print(f"The mean age in the sample is {mean_age:.2f}")
# Out:
# The mean age in the sample is 48.88

# %% [markdown]
# # Part 4

# %%
expend_summary = df['expend_total'].describe()
expend_summary
# Out:
# count    2887.000000
# mean       24.101489
# std        88.288585
# min         0.000000
# 25%         0.000000
# 50%         2.000000
# 75%        15.000000
# max      1900.000000
# Name: expend_total, dtype: float64

# %%
df['expenditures_share_income'] = df['expend_total'] / df['income']
# Out:
# C:\Users\clint\AppData\Local\Temp\ipykernel_37132\4120602394.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['expenditures_share_income'] = df['expend_total'] / df['income']

# %%
expenditures_share_income_summary = df['expenditures_share_income'].describe()
expenditures_share_income_summary
# Out:
# count    2887.000000
# mean        0.761211
# std         3.537560
# min         0.000000
# 25%         0.000000
# 50%         0.029630
# 75%         0.285714
# max        69.090909
# Name: expenditures_share_income, dtype: float64

# %%
import matplotlib.pyplot as plt

df['expend_total'].hist(bins=50)
plt.xlabel('Monthly Lottery Ticket Expenditures')
plt.ylabel('Frequency')
plt.title('Histogram of Monthly Lottery Ticket Expenditures')
plt.show()

# %% [markdown]
# # Part 5

# %%
education_thresholds = [5, 10, 15, 20]

for y in education_thresholds:
    df[f'education_{y}'] = df['education'].apply(lambda x: 1 if x >= y else 0)

df[['education', 'education_5', 'education_10', 'education_15', 'education_20']]
# Out:
# C:\Users\clint\AppData\Local\Temp\ipykernel_37132\4115323086.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'education_{y}'] = df['education'].apply(lambda x: 1 if x >= y else 0)
# C:\Users\clint\AppData\Local\Temp\ipykernel_37132\4115323086.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'education_{y}'] = df['education'].apply(lambda x: 1 if x >= y else 0)
# C:\Users\clint\AppData\Local\Temp\ipykernel_37132\4115323086.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'education_{y}'] = df['education'].apply(lambda x: 1 if x >= y else 0)
# C:\Users\clint\AppData\Local\Temp\ipykernel_37132\4115323086.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[f'education_{y}'] = df['education'].apply(lambda x: 1 if x >= y else 0)
#       education  education_5  education_10  education_15  education_20
# 0          18.0            1             1             1             0
# 1          14.0            1             1             0             0
# 2          18.0            1             1             1             0
# 3          12.0            1             1             0             0
# 4          13.0            1             1             0             0
# ...         ...          ...           ...           ...           ...
# 2885       12.0            1             1             0             0
# 2886       13.0            1             1             0             0
# 2887       20.0            1             1             1             1
# 2888       16.0            1             1             1             0
# 2889       12.0            1             1             0             0
#
# [2887 rows x 5 columns]

# %%
import seaborn as sns

sns.regplot(x='income_delta', y='expend_delta', data=df)
plt.xlabel('Income Delta')
plt.ylabel('Expenditure Delta')
plt.title('Scatter Plot of Income Delta vs Expenditure Delta with Regression Line')
plt.show()

# %%
import seaborn as sns

sns.regplot(x='income_effects_delta_pct', y='expend_delta', data=df)
plt.xlabel('Income Effects Delta Percentage')
plt.ylabel('Expenditure Delta')
plt.title('Scatter Plot of Income Effects Delta Percentage vs Expenditure Delta with Regression Line')
plt.show()

# %%
df.to_csv('lottery_study_updated.csv', index=False)
